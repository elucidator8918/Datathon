# %%
import numpy as np
from statsmodels.tsa.stattools import adfuller
from statsmodels.tsa.seasonal import seasonal_decompose
import statsmodels.api as smapi
from pmdarima.arima import auto_arima
from sklearn.metrics import mean_squared_error, mean_absolute_error
import math
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os
import pandas_profiling as pp
import warnings
warnings.filterwarnings('ignore')
# Out:
# /tmp/ipykernel_33774/2626448264.py:12: DeprecationWarning: `import pandas_profiling` is going to be deprecated by April 1st. Please use `import ydata_profiling` instead.
#   import pandas_profiling as pp

# %%
date_parser = lambda dates: pd.datetime.strptime(dates, '%Y-%m-%d')
infosys=pd.read_csv("INFY.csv",index_col='Date',parse_dates=['Date'],date_parser=date_parser).fillna(0)

# %%
ht=pp.ProfileReport(infosys)
ht.to_file("infosys.html")

# %%
infosys.head(20)
# Out:
#                Open     High      Low    Close  Adj Close    Volume
# Date
# 2009-01-02  3.06375  3.15625  3.02000  3.14375   2.306024  14917600
# 2009-01-05  3.09750  3.26750  3.09750  3.24875   2.383045  20835200
# 2009-01-06  3.25000  3.37375  3.22125  3.32500   2.438976  30572000
# 2009-01-07  3.16625  3.53875  3.14375  3.36750   2.470152  51324800
# 2009-01-08  3.33375  3.40625  3.28500  3.33000   2.442644  22020800
# 2009-01-09  3.41750  3.42375  3.22625  3.30875   2.427057  17408000
# 2009-01-12  3.20750  3.34750  3.19250  3.23500   2.372959  30562400
# 2009-01-13  3.40625  3.51875  3.32625  3.42500   2.512329  41921600
# 2009-01-14  3.41250  3.42375  3.28125  3.30375   2.423389  34449600
# 2009-01-15  3.30000  3.44125  3.23250  3.39375   2.489406  25572000
# 2009-01-16  3.45250  3.48125  3.35625  3.46250   2.539837  22836800
# 2009-01-20  3.40375  3.44000  3.27000  3.27125   2.399550  25332000
# 2009-01-21  3.25750  3.34625  3.19875  3.34250   2.451813  26825600
# 2009-01-22  3.28625  3.31250  3.12500  3.19125   2.340867  23449600
# 2009-01-23  3.12750  3.32375  3.12625  3.25750   2.389463  26676800
# 2009-01-26  3.28375  3.40375  3.26875  3.33750   2.448146  14914400
# 2009-01-27  3.37875  3.42250  3.33750  3.38875   2.485738  14131200
# 2009-01-28  3.47875  3.54750  3.45875  3.50500   2.571011  18325600
# 2009-01-29  3.49375  3.51750  3.41125  3.43250   2.517830  17109600
# 2009-01-30  3.42250  3.43875  3.29750  3.32000   2.435309  28686400

# %%
infosys.shape
# Out:
# (629, 6)

# %%
#plot close price
plt.figure(figsize=(10,6))
plt.grid(True)
plt.xlabel('Date')
plt.ylabel('Close Prices')
plt.plot(infosys['Close'])
plt.title('Infosys closing price')
plt.show()

# %%
df_close = infosys['Close']
df_close.plot(kind='kde')
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
def test_stationarity(timeseries):
    #Determing rolling statistics
    rolmean = timeseries.rolling(12).mean()
    rolstd = timeseries.rolling(12).std()
    #Plot rolling statistics:
    plt.plot(timeseries, color='blue',label='Original')
    plt.plot(rolmean, color='red', label='Rolling Mean')
    plt.plot(rolstd, color='black', label = 'Rolling Std')
    plt.legend(loc='best')
    plt.title('Rolling Mean and Standard Deviation')
    plt.show(block=False)
    print("Results of dickey fuller test")
    adft = adfuller(timeseries,autolag='AIC')
    # output for dft will give us without defining what the values are.
    #hence we manually write what values does it explains using a for loop
    output = pd.Series(adft[0:4],index=['Test Statistics','p-value','No. of lags used','Number of observations used'])
    for key,values in adft[4].items():
        output['critical value (%s)'%key] =  values
    print(output)
test_stationarity(df_close)
# Out:
# Results of dickey fuller test
# Test Statistics                 -1.754255
# p-value                          0.403397
# No. of lags used                 0.000000
# Number of observations used    628.000000
# critical value (1%)             -3.440806
# critical value (5%)             -2.866153
# critical value (10%)            -2.569227
# dtype: float64

# %%
result = seasonal_decompose(df_close, model='multiplicative',period=30)
fig = plt.figure()  
fig = result.plot()  
fig.set_size_inches(16, 9)

# %%
df_log = np.log(df_close)
moving_avg = df_log.rolling(12).mean()
std_dev = df_log.rolling(12).std()
plt.legend(loc='best')
plt.title('Moving Average')
plt.plot(std_dev, color ="black", label = "Standard Deviation")
plt.plot(moving_avg, color="red", label = "Mean")
plt.legend()
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
train_data, test_data = df_log[3:int(len(df_log)*0.9)], df_log[int(len(df_log)*0.9):]
plt.figure(figsize=(10,6))
plt.grid(True)
plt.xlabel('Dates')
plt.ylabel('Closing Prices')
plt.plot(df_log, 'green', label='Train data')
plt.plot(test_data, 'blue', label='Test data')
plt.legend()

# %%
model = smapi.tsa.arima.ARIMA(train_data, order=(4,2,10))
result = model.fit()
print(result.summary())
# Out:
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                  Close   No. Observations:                  563
# Model:                ARIMA(4, 2, 10)   Log Likelihood                1375.504
# Date:                Thu, 16 Feb 2023   AIC                          -2721.009
# Time:                        14:37:02   BIC                          -2656.063
# Sample:                             0   HQIC                         -2695.651
#                                 - 563
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1         -0.9017      0.159     -5.679      0.000      -1.213      -0.591
# ar.L2         -0.6191      0.105     -5.873      0.000      -0.826      -0.412
# ar.L3         -0.8991      0.136     -6.615      0.000      -1.165      -0.633
# ar.L4         -0.8167      0.144     -5.688      0.000      -1.098      -0.535
# ma.L1         -0.1784      0.167     -1.068      0.286      -0.506       0.149
# ma.L2         -0.3020      0.176     -1.712      0.087      -0.648       0.044
# ma.L3          0.3603      0.153      2.354      0.019       0.060       0.660
# ma.L4         -0.1285      0.157     -0.817      0.414      -0.437       0.180
# ma.L5         -0.8214      0.171     -4.797      0.000      -1.157      -0.486
# ma.L6          0.0543      0.054      1.002      0.316      -0.052       0.161
# ma.L7          0.0273      0.046      0.600      0.549      -0.062       0.117
# ma.L8         -0.0709      0.046     -1.538      0.124      -0.161       0.019
# ma.L9          0.0497      0.049      1.023      0.306      -0.045       0.145
# ma.L10         0.0416      0.044      0.940      0.347      -0.045       0.128
# sigma2         0.0004   2.08e-05     20.784      0.000       0.000       0.000
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.10   Jarque-Bera (JB):                68.53
# Prob(Q):                              0.75   Prob(JB):                         0.00
# Heteroskedasticity (H):               0.33   Skew:                             0.02
# Prob(H) (two-sided):                  0.00   Kurtosis:                         4.71
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).

# %%
res=result.forecast(63,alpha=0.01).to_frame()
test_data=test_data.to_frame()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_33774/1623530974.py in <module>
#       1 res=result.forecast(63,alpha=0.01).to_frame()
# ----> 2 test_data=test_data.to_frame()
#
# ~/anaconda3/lib/python3.9/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5573         ):
#    5574             return self[name]
# -> 5575         return object.__getattribute__(self, name)
#    5576
#    5577     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'to_frame'

# %%
from sklearn.metrics import mean_squared_log_error
RMSLE =  np.sqrt(mean_squared_log_error(test_data['Close'].to_numpy(),res['predicted_mean'].to_numpy()))
print('RMSLE:',RMSLE)
# Out:
# RMSLE: 0.02633467517511987

# %%
res
# Out:
#      predicted_mean
# 563        2.192727
# 564        2.188950
# 565        2.188564
# 566        2.188116
# 567        2.189189
# ..              ...
# 621        2.136419
# 622        2.135516
# 623        2.134616
# 624        2.133718
# 625        2.132821
#
# [63 rows x 1 columns]

# %%
test_data
# Out:
#                Close
# Date
# 2011-04-01  2.212524
# 2011-04-04  2.216346
# 2011-04-05  2.216482
# 2011-04-06  2.212934
# 2011-04-07  2.214710
# ...              ...
# 2011-06-24  2.053483
# 2011-06-27  2.070338
# 2011-06-28  2.082094
# 2011-06-29  2.087069
# 2011-06-30  2.098478
#
# [63 rows x 1 columns]

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from statsmodels.tsa.arima.model import ARIMA

# Read data from INFY.CSV file
data = pd.read_csv('INFY.csv')
sales = data['Close']

# Fit ARIMA model
model = ARIMA(sales, order=(4,2,10))
model_fit = model.fit()

# Forecast future sales for the next 10 years
forecast = model_fit.forecast(steps=10*12)

# Plot the forecasted sales
plt.plot(sales)
plt.plot(forecast)
plt.title('Stock Forecast for the Next 10 Years')
plt.xlabel('Year')
plt.ylabel('Stocks')
plt.legend(['Historical Sales', 'Forecasted Sales'])
plt.show()
